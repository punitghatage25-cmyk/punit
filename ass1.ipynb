# %%
price = 2000
gst = price * 18 / 100
total_bill = price + gst
print("Product Price:", price)
print("GST:", gst)
print("Total Bill Amount:", total_bill)
# Out:
# Product Price: 2000
# GST: 360.0
# Total Bill Amount: 2360.0
